# %%
# %%HTML
#
# <link href="//netdna.bootstrapcdn.com/font-awesome/4.0.3/css/font-awesome.css" rel="stylesheet">
#
# <div id='topNav'>
#     <canvas id='GRSIlogo' width='160' height='60'></canvas>
#     <button id='hideGuts' onclick='hide()'>Hide Code</button>
#     <div class='headerLinks' id='showGuts' onclick='show()'>Under The Hood</div>
#     <a class='headerLinks' id='ourRepo' href='https://github.com/GRIFFINCollaboration/GRSISpoon'>Github</a>
#     <a class='headerLinks' id='IPython' href='http://ipython.org/notebook.html'>IPython</a>
# </div>
# <p id='tagBlock'>GRSISpoon Web Control</p>
# <script type="text/javascript">
#
#     var widgetSpan = document.getElementById('hideGuts').parentNode.parentNode.parentNode.parentNode.parentNode.parentNode.id = 'internalHeader';
#
#     function hide(){
#         $('div.input').hide();
#         $('div.out_prompt_overlay.prompt').hide();
#         $('div.prompt.output_prompt').hide();
#         $('div#header').hide();
#         $('div#menubar-container').hide();
#         $('div#pager').hide();
#         $('button#hideGuts').hide();
#         $('div#showGuts').show();
#     }
#
#     function show(){
#         $('div.input').show();
#         $('div.out_prompt_overlay.prompt').show();
#         $('div.prompt.output_prompt').show();
#         $('div#header').show();
#         $('div#menubar-container').show();
#         $('div#pager').show();
#         $('button#hideGuts').show();
#         $('div#showGuts').hide();
#     }
# </script>
# Out:
# <link href="//netdna.bootstrapcdn.com/font-awesome/4.0.3/css/font-awesome.css" rel="stylesheet">
#
# <div id='topNav'>
#     <canvas id='GRSIlogo' width='160' height='60'></canvas>
#     <button id='hideGuts' onclick='hide()'>Hide Code</button>
#     <div class='headerLinks' id='showGuts' onclick='show()'>Under The Hood</div>
#     <a class='headerLinks' id='ourRepo' href='https://github.com/GRIFFINCollaboration/GRSISpoon'>Github</a>
#     <a class='headerLinks' id='IPython' href='http://ipython.org/notebook.html'>IPython</a>
# </div>
# <p id='tagBlock'>GRSISpoon Web Control</p>
# <script type="text/javascript">
#
#     var widgetSpan = document.getElementById('hideGuts').parentNode.parentNode.parentNode.parentNode.parentNode.parentNode.id = 'internalHeader';
#
#     function hide(){
#         $('div.input').hide();
#         $('div.out_prompt_overlay.prompt').hide();
#         $('div.prompt.output_prompt').hide();
#         $('div#header').hide();
#         $('div#menubar-container').hide();
#         $('div#pager').hide();
#         $('button#hideGuts').hide();
#         $('div#showGuts').show();
#     }
#
#     function show(){
#         $('div.input').show();
#         $('div.out_prompt_overlay.prompt').show();
#         $('div.prompt.output_prompt').show();
#         $('div#header').show();
#         $('div#menubar-container').show();
#         $('div#pager').show();
#         $('button#hideGuts').show();
#         $('div#showGuts').hide();
#     }
# </script>

# %%
# %%HTML
#
# <ul class='fileList' id='unselectedFiles'>
#     <li class='fileShowing' onclick='selectItem(this)' onmousedown='initiateFileRangeSelect'>Apples</li>
#     <li class='fileShowing' onclick='selectItem(this)'>Oranges</li>
#     <li class='fileShowing' onclick='selectItem(this)'>Pears</li>
#     <li class='fileShowing' onclick='selectItem(this)'>Sushi</li>
# </ul>
#
# <ul class='fileList' id='selectedFiles'>
#     <li class='fileHidden' onclick='unselectItem(this)'>Apples</li>
#     <li class='fileHidden' onclick='unselectItem(this)'>Oranges</li>
#     <li class='fileHidden' onclick='unselectItem(this)'>Pears</li>
#     <li class='fileHidden' onclick='unselectItem(this)'>Sushi</li>
#     <div id='fileWidgetHint'>
#         Click a file from the list on the left to queue it up for sorting; hold down shift to select a range of files, or use the text box below to match files by name.
#     </div>
# </ul>
#
# <script>
#     var widgetSpan = document.getElementById('unselectedFiles').parentNode.parentNode.parentNode.parentNode.parentNode.id = 'fileBrowserWidget';
#
#     //hide an item in the unselected list, and show it in the selected list
#     function selectItem(target){
#         var selectedFileList = document.getElementById('selectedFiles'),
#             i;
#
#         for(i=0; i<selectedFileList.children.length; i++){
#             if(selectedFileList.children[i].innerHTML == target.innerHTML){
#                 target.className = 'fileHidden';
#                 selectedFileList.children[i].className = 'fileShowing';
#                 break;
#             }
#         }
#
#         //don't need the hint anymore, hide it
#         document.getElementById('fileWidgetHint').style.display = 'none';
#
#         stripeList()
#     }
#
#     //inverse of selectItem
#     function unselectItem(target){
#         var unselectedFileList = document.getElementById('unselectedFiles'),
#             i;
#
#         for(i=0; i<unselectedFileList.children.length; i++){
#             if(unselectedFileList.children[i].innerHTML == target.innerHTML){
#                 target.className = 'fileHidden';
#                 unselectedFileList.children[i].className = 'fileShowing';
#                 break;
#             }
#         }
#
#         stripeList();
#     }
#
#     //mousedown behavior to accommodate selecting a range of files:
#     function initiateFileRangeSelect(event){
#
#         //only do this if shift is down:
#         if(!event.shiftKey) return;
#
#         //flag that we are in range select mode
#         window.selectFileMode = true;
#
#         event.target.className += ' fileSelected';
#     }
#
#     //mouseover behavior for selecting a range of files:
#     function selectFileRange(event){
#
#         //only do this in select file range mode:
#         if(!window.selectFileMode) return;
#
#         //highlight if it isn't highlighted
#         if(event.target.className.indexOf('fileSelected') == -1)
#             event.target.className += ' fileSelected';
#         //unhighlight the previous file if it is highlighted
#         else
#             //event.target.className = event.target.className.slice(0, ' ');
#             window.lastFileLeft.className = window.lastFileLeft.className.slice(0, ' ');
#     }
#
#     //mouseout behavior for selecting a range of files
#     function mouseoutFileRange(event){
#
#         //only do this in select file range mode:
#         if(!window.selectFileMode) return;
#
#         //keep track of the last element the user left
#         window.lastFileLeft = event.target;
#
#     }
#
#     //mouseup behavior for selecting range of files
#     function finishFileRange(event){
#
#         //only do this in select file range mode:
#         if(!window.selectFileMode) return;
#
#         //leave file selection mode
#         window.selectFileMode = false;
#
#         //unhighlight and 'click' every file that's been highlighted:
#         var fileElts = document.querySelectorAll('ul.fileList li.fileSelected');
#         [].forEach.call(fileElts, function(elt){
#             //unhighlight:
#             elt.className = elt.className.slice(0, ' ');
#
#             //move to the other list:
#             elt.onclick();
#         })
#     }
#
#     //add event listeners to all file list elements:
#     var fileElts = document.querySelectorAll('ul.fileList li');
#     [].forEach.call(fileElts, function(elt){
#         elt.addEventListener('mousedown', initiateFileRangeSelect, false);
#         elt.addEventListener('mouseover', selectFileRange, false);
#         elt.addEventListener('mouseup', finishFileRange, false);
#         elt.addEventListener('mouseout', mouseoutFileRange, false);
#     })
#
#     //if the user leaves the list of files and mouseups over the ul background, execute the swap;
#     //if the user leaves the ul altogether, execute the swap:
#     var listElts = document.querySelectorAll('ul.fileList');
#     [].forEach.call(listElts, function(elt){
#         elt.addEventListener('mouseup', finishFileRange, false);
#         elt.addEventListener('mouseout', function(event){
#             //make sure mousing over a child of the ul doesn't get counted as a mouseout:
#             var e = event.toElement || event.relatedTarget;
#             if (e.parentNode == this || e == this) {
#                return;
#             }
#
#             //nope, definitely moused out, time to bail:
#             finishFileRange(event);
#         }, false);
#     })
#
#
#     //css lacks a nth-of-class; fake it with jquery:
#     function stripeList(){
#         $('ul#unselectedFiles li').filter(function(){
#                                          return !$(this).hasClass('fileHidden');
#                                      }).filter(function(i){
#                                                    return (i+1)%2 == 0;
#         }).css('background-color','#ecf0f1');
#
#         $('ul#unselectedFiles li').filter(function(){
#                                          return !$(this).hasClass('fileHidden');
#                                      }).filter(function(i){
#                                                    return i%2 == 0;
#         }).css('background-color','#DCE0E1');
#
#         $('ul#selectedFiles li').filter(function(){
#                                          return !$(this).hasClass('fileHidden');
#                                      }).filter(function(i){
#                                                    return (i+1)%2 == 0;
#         }).css('background-color','#5efca1');
#
#         $('ul#selectedFiles li').filter(function(){
#                                          return !$(this).hasClass('fileHidden');
#                                      }).filter(function(i){
#                                                    return i%2 == 0;
#         }).css('background-color','#4eec91');
#     }
#
#     stripeList()
# </script>
# Out:
# <ul class='fileList' id='unselectedFiles'>
#     <li class='fileShowing' onclick='selectItem(this)' onmousedown='initiateFileRangeSelect'>Apples</li>
#     <li class='fileShowing' onclick='selectItem(this)'>Oranges</li>
#     <li class='fileShowing' onclick='selectItem(this)'>Pears</li>
#     <li class='fileShowing' onclick='selectItem(this)'>Sushi</li>
# </ul>
#
# <ul class='fileList' id='selectedFiles'>
#     <li class='fileHidden' onclick='unselectItem(this)'>Apples</li>
#     <li class='fileHidden' onclick='unselectItem(this)'>Oranges</li>
#     <li class='fileHidden' onclick='unselectItem(this)'>Pears</li>
#     <li class='fileHidden' onclick='unselectItem(this)'>Sushi</li>
#     <div id='fileWidgetHint'>
#         Click a file from the list on the left to queue it up for sorting; hold down shift to select a range of files, or use the text box below to match files by name.
#     </div>
# </ul>
#
# <script>
#     var widgetSpan = document.getElementById('unselectedFiles').parentNode.parentNode.parentNode.parentNode.parentNode.id = 'fileBrowserWidget';
#
#     //hide an item in the unselected list, and show it in the selected list
#     function selectItem(target){
#         var selectedFileList = document.getElementById('selectedFiles'),
#             i;
#
#         for(i=0; i<selectedFileList.children.length; i++){
#             if(selectedFileList.children[i].innerHTML == target.innerHTML){
#                 target.className = 'fileHidden';
#                 selectedFileList.children[i].className = 'fileShowing';
#                 break;
#             }
#         }
#
#         //don't need the hint anymore, hide it
#         document.getElementById('fileWidgetHint').style.display = 'none';
#
#         stripeList()
#     }
#
#     //inverse of selectItem
#     function unselectItem(target){
#         var unselectedFileList = document.getElementById('unselectedFiles'),
#             i;
#
#         for(i=0; i<unselectedFileList.children.length; i++){
#             if(unselectedFileList.children[i].innerHTML == target.innerHTML){
#                 target.className = 'fileHidden';
#                 unselectedFileList.children[i].className = 'fileShowing';
#                 break;
#             }
#         }
#
#         stripeList();
#     }
#
#     //mousedown behavior to accommodate selecting a range of files:
#     function initiateFileRangeSelect(event){
#
#         //only do this if shift is down:
#         if(!event.shiftKey) return;
#
#         //flag that we are in range select mode
#         window.selectFileMode = true;
#
#         event.target.className += ' fileSelected';
#     }
#
#     //mouseover behavior for selecting a range of files:
#     function selectFileRange(event){
#
#         //only do this in select file range mode:
#         if(!window.selectFileMode) return;
#
#         //highlight if it isn't highlighted
#         if(event.target.className.indexOf('fileSelected') == -1)
#             event.target.className += ' fileSelected';
#         //unhighlight the previous file if it is highlighted
#         else
#             //event.target.className = event.target.className.slice(0, ' ');
#             window.lastFileLeft.className = window.lastFileLeft.className.slice(0, ' ');
#     }
#
#     //mouseout behavior for selecting a range of files
#     function mouseoutFileRange(event){
#
#         //only do this in select file range mode:
#         if(!window.selectFileMode) return;
#
#         //keep track of the last element the user left
#         window.lastFileLeft = event.target;
#
#     }
#
#     //mouseup behavior for selecting range of files
#     function finishFileRange(event){
#
#         //only do this in select file range mode:
#         if(!window.selectFileMode) return;
#
#         //leave file selection mode
#         window.selectFileMode = false;
#
#         //unhighlight and 'click' every file that's been highlighted:
#         var fileElts = document.querySelectorAll('ul.fileList li.fileSelected');
#         [].forEach.call(fileElts, function(elt){
#             //unhighlight:
#             elt.className = elt.className.slice(0, ' ');
#
#             //move to the other list:
#             elt.onclick();
#         })
#     }
#
#     //add event listeners to all file list elements:
#     var fileElts = document.querySelectorAll('ul.fileList li');
#     [].forEach.call(fileElts, function(elt){
#         elt.addEventListener('mousedown', initiateFileRangeSelect, false);
#         elt.addEventListener('mouseover', selectFileRange, false);
#         elt.addEventListener('mouseup', finishFileRange, false);
#         elt.addEventListener('mouseout', mouseoutFileRange, false);
#     })
#
#     //if the user leaves the list of files and mouseups over the ul background, execute the swap;
#     //if the user leaves the ul altogether, execute the swap:
#     var listElts = document.querySelectorAll('ul.fileList');
#     [].forEach.call(listElts, function(elt){
#         elt.addEventListener('mouseup', finishFileRange, false);
#         elt.addEventListener('mouseout', function(event){
#             //make sure mousing over a child of the ul doesn't get counted as a mouseout:
#             var e = event.toElement || event.relatedTarget;
#             if (e.parentNode == this || e == this) {
#                return;
#             }
#
#             //nope, definitely moused out, time to bail:
#             finishFileRange(event);
#         }, false);
#     })
#
#
#     //css lacks a nth-of-class; fake it with jquery:
#     function stripeList(){
#         $('ul#unselectedFiles li').filter(function(){
#                                          return !$(this).hasClass('fileHidden');
#                                      }).filter(function(i){
#                                                    return (i+1)%2 == 0;
#         }).css('background-color','#ecf0f1');
#
#         $('ul#unselectedFiles li').filter(function(){
#                                          return !$(this).hasClass('fileHidden');
#                                      }).filter(function(i){
#                                                    return i%2 == 0;
#         }).css('background-color','#DCE0E1');
#
#         $('ul#selectedFiles li').filter(function(){
#                                          return !$(this).hasClass('fileHidden');
#                                      }).filter(function(i){
#                                                    return (i+1)%2 == 0;
#         }).css('background-color','#5efca1');
#
#         $('ul#selectedFiles li').filter(function(){
#                                          return !$(this).hasClass('fileHidden');
#                                      }).filter(function(i){
#                                                    return i%2 == 0;
#         }).css('background-color','#4eec91');
#     }
#
#     stripeList()
# </script>

# %%
# %%HTML
#
# <div id='testwrap'>
# <select id='plotOptions'></select>
# <img id='imgtarget'></img>
# <button id='fetchplot' onclick='exec_code()'>Plot</button>
# </div>
#
# <script>
#     var widgetSpan = document.getElementById('testwrap').parentNode.parentNode.parentNode.parentNode.parentNode.id = 'plotWidget';
# </script>
# Out:
# <div id='testwrap'>
# <select id='plotOptions'></select>
# <img id='imgtarget'></img>
# <button id='fetchplot' onclick='exec_code()'>Plot</button>
# </div>
#
# <script>
#     var widgetSpan = document.getElementById('testwrap').parentNode.parentNode.parentNode.parentNode.parentNode.id = 'plotWidget';
# </script>

# %%
# %%HTML
#
# <h2>System Load Monitor</h2>
#
# <canvas id='systemUseCanvas'></canvas>
#
# <script>
#     var widgetSpan = document.getElementById('systemUseCanvas').parentNode.parentNode.parentNode.parentNode.parentNode.id = 'systemUseWidget';
# </script>
# Out:
# <h2>System Load Monitor</h2>
#
# <canvas id='systemUseCanvas'></canvas>
#
# <script>
#     var widgetSpan = document.getElementById('systemUseCanvas').parentNode.parentNode.parentNode.parentNode.parentNode.id = 'systemUseWidget';
# </script>
